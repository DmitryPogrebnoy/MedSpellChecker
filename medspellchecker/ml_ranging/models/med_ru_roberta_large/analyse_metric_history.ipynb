# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 14})

# %%
EARLY_STOP_NUMBER = 3

# %%
df_with_updated_tokenizer = pd.read_csv("../../../../data/ml/ru_roberta_large_finetuned/metric_history_without_updated_tokenizer.csv", index_col=0)
df_with_updated_tokenizer.head()
# Out:
#    train_perplexity  train_mean_loss  test_perplexity  test_mean_loss
# 0         55.640341         4.018909        21.645413        3.074794
# 1         23.036935         3.137099        19.800672        2.985716
# 2         17.031972         2.835092        15.886180        2.765449
# 3         11.962482         2.481775        13.373343        2.593263
# 4         11.989736         2.484051         9.999123        2.302497

# %%
df_with_updated_tokenizer
# Out:
#     train_perplexity  train_mean_loss  test_perplexity  test_mean_loss
# 0          55.640341         4.018909        21.645413        3.074794
# 1          23.036935         3.137099        19.800672        2.985716
# 2          17.031972         2.835092        15.886180        2.765449
# 3          11.962482         2.481775        13.373343        2.593263
# 4          11.989736         2.484051         9.999123        2.302497
# ..               ...              ...              ...             ...
# 95          3.748133         1.321258         3.974355        1.379862
# 96          3.665211         1.298886         6.626838        1.891128
# 97          4.087557         1.407947         5.858380        1.767873
# 98          4.338020         1.467418         2.891263        1.061693
# 99          3.248775         1.178278         6.654583        1.895306
#
# [100 rows x 4 columns]

# %%
def find_start_first_non_decreased_sequent(series_data, window):
    rolled_data = series_data.rolling(window).apply(lambda x: all(i < j for i, j in zip(x, x[1:]))).fillna(0.0)
    increased_values_iter = [idx for idx, x in enumerate(rolled_data) if x > 0.0]
    if len(increased_values_iter):
        return increased_values_iter[0] - 1
    else:
        return None

# %%
find_start_first_non_decreased_sequent(df_with_updated_tokenizer.test_perplexity, EARLY_STOP_NUMBER)
# Out:
# 12

# %%
df_with_updated_tokenizer
# Out:
#     train_perplexity  train_mean_loss  test_perplexity  test_mean_loss
# 0          55.640341         4.018909        21.645413        3.074794
# 1          23.036935         3.137099        19.800672        2.985716
# 2          17.031972         2.835092        15.886180        2.765449
# 3          11.962482         2.481775        13.373343        2.593263
# 4          11.989736         2.484051         9.999123        2.302497
# ..               ...              ...              ...             ...
# 95          3.748133         1.321258         3.974355        1.379862
# 96          3.665211         1.298886         6.626838        1.891128
# 97          4.087557         1.407947         5.858380        1.767873
# 98          4.338020         1.467418         2.891263        1.061693
# 99          3.248775         1.178278         6.654583        1.895306
#
# [100 rows x 4 columns]

# %%
def plot_perplexity_and_loss(df, first, second):
    fig, ax = plt.subplots(nrows=1)

    fig.set_size_inches(15,8)

    df.index += 1

    df.train_perplexity.plot(ax=ax, label="Train Perplexity")
    df.test_perplexity.plot(ax=ax, label="Test Perplexity", color="g")
    ax.set_title("Train and Test Perplexity")
    ax_0_lim = ax.get_ylim()
    # ax[0].vlines(x=first, ymin=ax_0_lim[0], ymax=ax_0_lim[1], colors="r")
    # ax[0].vlines(x=second, ymin=ax_0_lim[0], ymax=ax_0_lim[1], colors="r")
    ax.legend()

    # df.train_mean_loss.plot(ax=ax[1], label="Train Mean Loss")
    # df.test_mean_loss.plot(ax=ax[1], label="Test Mean Loss", color="g")
    # ax[1].set_title("Train and Test Mean Loss")
    # ax_1_lim = ax[1].get_ylim()
    # ax[1].vlines(x=first, ymin=ax_1_lim[0], ymax=ax_1_lim[1], colors="r")
    # ax[1].vlines(x=second, ymin=ax_1_lim[0], ymax=ax_1_lim[1], colors="r")
    # ax[1].legend()

    plt.show()

# %%
plot_perplexity_and_loss(df_with_updated_tokenizer[:10], -1, -1)

# %%
df = pd.read_csv("../../../../data/ml/ru_roberta_large_finetuned/metric_history.csv", index_col=0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv("../../../../data/ml/ru_roberta_large_finetuned/metric_history.csv", index_col=0)
#       2 df.head()
#
# File ~\Desktop\MedSpellChecker\venv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Desktop\MedSpellChecker\venv\lib\site-packages\pandas\io\parsers\readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File ~\Desktop\MedSpellChecker\venv\lib\site-packages\pandas\io\parsers\readers.py:482, in _read(filepath_or_buffer, kwds)
#     479 _validate_names(kwds.get("names", None))
#     481 # Create the parser.
# --> 482 parser = TextFileReader(filepath_or_buffer, **kwds)
#     484 if chunksize or iterator:
#     485     return parser
#
# File ~\Desktop\MedSpellChecker\venv\lib\site-packages\pandas\io\parsers\readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     808 if "has_index_names" in kwds:
#     809     self.options["has_index_names"] = kwds["has_index_names"]
# --> 811 self._engine = self._make_engine(self.engine)
#
# File ~\Desktop\MedSpellChecker\venv\lib\site-packages\pandas\io\parsers\readers.py:1040, in TextFileReader._make_engine(self, engine)
#    1036     raise ValueError(
#    1037         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1038     )
#    1039 # error: Too many arguments for "ParserBase"
# -> 1040 return mapping[engine](self.f, **self.options)
#
# File ~\Desktop\MedSpellChecker\venv\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:51, in CParserWrapper.__init__(self, src, **kwds)
#      48 kwds["usecols"] = self.usecols
#      50 # open handles
# ---> 51 self._open_handles(src, kwds)
#      52 assert self.handles is not None
#      54 # Have to pass int, would break tests using TextReader directly otherwise :(
#
# File ~\Desktop\MedSpellChecker\venv\lib\site-packages\pandas\io\parsers\base_parser.py:222, in ParserBase._open_handles(self, src, kwds)
#     218 def _open_handles(self, src: FilePathOrBuffer, kwds: dict[str, Any]) -> None:
#     219     """
#     220     Let the readers open IOHandles after they are done with their potential raises.
#     221     """
# --> 222     self.handles = get_handle(
#     223         src,
#     224         "r",
#     225         encoding=kwds.get("encoding", None),
#     226         compression=kwds.get("compression", None),
#     227         memory_map=kwds.get("memory_map", False),
#     228         storage_options=kwds.get("storage_options", None),
#     229         errors=kwds.get("encoding_errors", "strict"),
#     230     )
#
# File ~\Desktop\MedSpellChecker\venv\lib\site-packages\pandas\io\common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../../data/ml/ru_roberta_large_finetuned/metric_history.csv'

# %%
find_start_first_non_decreased_sequent(df.test_perplexity, EARLY_STOP_NUMBER)

# %%
plot_perplexity_and_loss(df,5,12)

# %% [markdown]
# # Decision
# Let's leave tokenizer untouched and fine tune the model in 10 epoch, so I believe it's enough for finetuning and for keep the model non-overfitted
